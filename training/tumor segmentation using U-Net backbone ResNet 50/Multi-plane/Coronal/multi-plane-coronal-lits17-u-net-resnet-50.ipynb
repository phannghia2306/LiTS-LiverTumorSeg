# %%
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
import random
from sklearn.model_selection import train_test_split
import shutil
# %matplotlib inline

# %%
from tensorflow import keras
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.compat.v1 import image
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D, UpSampling2D, Conv2DTranspose, GlobalAveragePooling2D
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, Lambda
from tensorflow.keras.layers import BatchNormalization, Activation, concatenate, multiply, add
from tensorflow.keras.layers import ReLU, LeakyReLU, PReLU, ELU, Softmax
from tensorflow.keras.activations import sigmoid

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
from cv2 import imread, createCLAHE 
from glob import glob

from IPython.display import clear_output
from tensorflow.keras.optimizers import Adam 
from sklearn.model_selection import train_test_split

# %%
from tensorflow.keras.models import *
from tensorflow.python.keras.utils.data_utils import Sequence
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import layers

def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)
def iou_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (keras.sum(y_true_f) + keras.sum(y_pred_f) - intersection + 1.0)

# %%
from tensorflow.keras.models import load_model

model = load_model('../input/savemodels/models/tumor-liver-crops-512x512_weights_best.h5')
# Out:
# 2022-05-19 07:31:57.524991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:57.666326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:57.667204: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:57.668351: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-19 07:31:57.668717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:57.669524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:57.670190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:59.905970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:59.906755: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:59.907496: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-19 07:31:59.909027: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
def adjustData(img,mask,flag_multi_class,num_class):
    if(flag_multi_class):
        img = (img - img.min()) / (img.max() - img.min())
        mask = mask[:,:,:,0] if(len(mask.shape) == 4) else mask[:,:,0]
        new_mask = np.zeros(mask.shape + (num_class,))
        for i in range(num_class):
            #for one pixel in the image, find the class in mask and convert it into one-hot vector
            #index = np.where(mask == i)
            #index_mask = (index[0],index[1],index[2],np.zeros(len(index[0]),dtype = np.int64) + i) if (len(mask.shape) == 4) else (index[0],index[1],np.zeros(len(index[0]),dtype = np.int64) + i)
            #new_mask[index_mask] = 1
            new_mask[mask == i,i] = 1
        new_mask = np.reshape(new_mask,(new_mask.shape[0],new_mask.shape[1]*new_mask.shape[2],new_mask.shape[3])) if flag_multi_class else np.reshape(new_mask,(new_mask.shape[0]*new_mask.shape[1],new_mask.shape[2]))
        mask = new_mask
    elif(np.max(img) > 1):
        img = (img - img.min()) / (img.max() - img.min())
        mask = mask / 255
        mask[mask > 0.5] = 1
        mask[mask <= 0.5] = 0
    return (img, mask)

def trainGenerator(batch_size,train_path,image_folder,
                   mask_folder,
                   aug_dict,
                   image_color_mode = "rgb",
                   mask_color_mode = "grayscale",
                   image_save_prefix  = "image",
                   mask_save_prefix  = "mask",
                   flag_multi_class = False,
                   num_class = 2,
                   save_to_dir = None,
                   target_size = (256,256),
                   seed = 1,
                   subset = 'training'):
    '''
    can generate image and mask at the same time
    use the same seed for image_datagen and mask_datagen to ensure the transformation for image and mask is the same
    if you want to visualize the results of generator, set save_to_dir = "your path"
    '''
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    image_generator = image_datagen.flow_from_directory(
        train_path,
        classes = [image_folder],
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed,
        subset = subset)
    mask_generator = mask_datagen.flow_from_directory(
        train_path,
        classes = [mask_folder],
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed,
        subset = subset)
    train_generator = zip(image_generator, mask_generator)
    for (img,mask) in train_generator:
        img,mask = adjustData(img,mask,flag_multi_class,num_class)
        yield (img,mask)

# %%
data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.1,
                    height_shift_range=0.1,
                    shear_range=0.05,
                    zoom_range=0.1,
                    horizontal_flip=True,
                    vertical_flip=True,
                    fill_mode='nearest',
                    validation_split=0)


train_generator = trainGenerator(8,'../input/tumorsegmentationmultiplane/tumor_seg_multiplane/tumor_seg_coronal/train','CT_images','Tumor_masks',data_gen_args,save_to_dir = None,
                                target_size = (512, 512))
valid_generator = trainGenerator(8,'../input/tumorsegmentationmultiplane/tumor_seg_multiplane/tumor_seg_coronal/valid','CT_images','Tumor_masks',data_gen_args,save_to_dir = None,
                                target_size = (512, 512))

# %%
def display(display_list):
    plt.figure(figsize=(15,15))
    
    title = ['Input Image', 'True Mask', 'Predicted Mask']
    
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]), cmap='gray')
    plt.show()
def show_dataset(datagen, num=1):
    for i in range(0,num):
        image,mask = next(datagen)
        display([image[0], mask[0]])

# %%
show_dataset(train_generator, 5)
# Out:
# Found 10000 images belonging to 1 classes.
# Found 10000 images belonging to 1 classes.

# %%
show_dataset(valid_generator, 5)
# Out:
# Found 2500 images belonging to 1 classes.
# Found 2500 images belonging to 1 classes.

# %%
model.compile(optimizer=Adam(learning_rate=1e-5), loss=dice_coef_loss,
                  metrics=[dice_coef, iou_coef])

# %%
weights = 'weights'
os.mkdir(weights)
log = 'log'
os.mkdir(log)

# %%
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="./weights/{}_weights_best.hdf5".format('tumor-sagittal-crops-512x512')

model_checkpoint = ModelCheckpoint(weight_path, monitor='val_dice_coef', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)

model_tensorboard = TensorBoard('./', write_graph=True, write_images=True)
reduce_lr = ReduceLROnPlateau(factor=0.5, patience=4, min_lr=1e-08)
model_earlystop = EarlyStopping(monitor="val_dice_coef", 
                      mode="max", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited

model_callbacks = [model_checkpoint,
                   model_tensorboard,
                   reduce_lr,
                   model_earlystop]
# Out:
# 2022-05-19 07:32:23.337398: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-05-19 07:32:23.337436: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-05-19 07:32:23.339628: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2022-05-19 07:32:23.597434: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-05-19 07:32:23.597609: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %%
num_train = 10000
num_valid = 2500

train_batchsize = 8
valid_batchsize = 8

Step_train = num_train // train_batchsize
Step_valid = num_valid // valid_batchsize
epochs = 28

# %%
history = model.fit(train_generator,
                    steps_per_epoch=Step_train,
                    epochs=epochs,
                    validation_data=valid_generator,
                    validation_steps=Step_valid,
                    verbose=1,
                    callbacks=model_callbacks)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 2022-05-19 07:32:25.106361: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/28
# 2022-05-19 07:32:31.058066: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
#    1/1250 [..............................] - ETA: 5:59:53 - loss: 0.3456 - dice_coef: 0.6544 - iou_coef: 0.4863
# 2022-05-19 07:32:42.551274: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-05-19 07:32:42.551328: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#    2/1250 [..............................] - ETA: 23:35 - loss: 0.3787 - dice_coef: 0.6213 - iou_coef: 0.4515
# 2022-05-19 07:32:43.561857: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-05-19 07:32:43.564398: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-05-19 07:32:43.738847: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 1538 callback api events and 1534 activity events.
# 2022-05-19 07:32:43.780058: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-05-19 07:32:43.835662: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./train/plugins/profile/2022_05_19_07_32_43
#
# 2022-05-19 07:32:43.859657: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ./train/plugins/profile/2022_05_19_07_32_43/c62ef07e0c90.trace.json.gz
# 2022-05-19 07:32:43.942076: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ./train/plugins/profile/2022_05_19_07_32_43
#
# 2022-05-19 07:32:43.948869: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ./train/plugins/profile/2022_05_19_07_32_43/c62ef07e0c90.memory_profile.json.gz
# 2022-05-19 07:32:43.952568: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ./train/plugins/profile/2022_05_19_07_32_43
# Dumped tool data for xplane.pb to ./train/plugins/profile/2022_05_19_07_32_43/c62ef07e0c90.xplane.pb
# Dumped tool data for overview_page.pb to ./train/plugins/profile/2022_05_19_07_32_43/c62ef07e0c90.overview_page.pb
# Dumped tool data for input_pipeline.pb to ./train/plugins/profile/2022_05_19_07_32_43/c62ef07e0c90.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ./train/plugins/profile/2022_05_19_07_32_43/c62ef07e0c90.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ./train/plugins/profile/2022_05_19_07_32_43/c62ef07e0c90.kernel_stats.pb
# 1250/1250 [==============================] - 1368s 1s/step - loss: 0.3623 - dice_coef: 0.6377 - iou_coef: 0.5056 - val_loss: 0.3890 - val_dice_coef: 0.6101 - val_iou_coef: 0.4709
#
# Epoch 00001: val_dice_coef improved from -inf to 0.61007, saving model to ./weights/tumor-sagittal-crops-512x512_weights_best.hdf5
# Epoch 2/28
# 1250/1250 [==============================] - 1314s 1s/step - loss: 0.3193 - dice_coef: 0.6807 - iou_coef: 0.5483 - val_loss: 0.3830 - val_dice_coef: 0.6170 - val_iou_coef: 0.4775
#
# Epoch 00002: val_dice_coef improved from 0.61007 to 0.61704, saving model to ./weights/tumor-sagittal-crops-512x512_weights_best.hdf5
# Epoch 3/28
# 1250/1250 [==============================] - 1326s 1s/step - loss: 0.2977 - dice_coef: 0.7023 - iou_coef: 0.5742 - val_loss: 0.3942 - val_dice_coef: 0.6062 - val_iou_coef: 0.4646
#
# Epoch 00003: val_dice_coef did not improve from 0.61704
# Epoch 4/28
# 1250/1250 [==============================] - 1354s 1s/step - loss: 0.2804 - dice_coef: 0.7196 - iou_coef: 0.5936 - val_loss: 0.3682 - val_dice_coef: 0.6318 - val_iou_coef: 0.4913
#
# Epoch 00004: val_dice_coef improved from 0.61704 to 0.63180, saving model to ./weights/tumor-sagittal-crops-512x512_weights_best.hdf5
# Epoch 5/28
# 1250/1250 [==============================] - 1367s 1s/step - loss: 0.2731 - dice_coef: 0.7269 - iou_coef: 0.6016 - val_loss: 0.3756 - val_dice_coef: 0.6247 - val_iou_coef: 0.4836
#
# Epoch 00005: val_dice_coef did not improve from 0.63180
# Epoch 6/28
# 1250/1250 [==============================] - 1387s 1s/step - loss: 0.2609 - dice_coef: 0.7391 - iou_coef: 0.6153 - val_loss: 0.3826 - val_dice_coef: 0.6173 - val_iou_coef: 0.4781
#
# Epoch 00006: val_dice_coef did not improve from 0.63180
# Epoch 7/28
# 1250/1250 [==============================] - 1363s 1s/step - loss: 0.2637 - dice_coef: 0.7363 - iou_coef: 0.6161 - val_loss: 0.3848 - val_dice_coef: 0.6154 - val_iou_coef: 0.4802
#
# Epoch 00007: val_dice_coef did not improve from 0.63180
# Epoch 8/28
# 1250/1250 [==============================] - 1390s 1s/step - loss: 0.2455 - dice_coef: 0.7545 - iou_coef: 0.6335 - val_loss: 0.3659 - val_dice_coef: 0.6331 - val_iou_coef: 0.4966
#
# Epoch 00008: val_dice_coef improved from 0.63180 to 0.63306, saving model to ./weights/tumor-sagittal-crops-512x512_weights_best.hdf5
# Epoch 9/28
# 1250/1250 [==============================] - 1369s 1s/step - loss: 0.2395 - dice_coef: 0.7605 - iou_coef: 0.6404 - val_loss: 0.3510 - val_dice_coef: 0.6490 - val_iou_coef: 0.5111
#
# Epoch 00009: val_dice_coef improved from 0.63306 to 0.64899, saving model to ./weights/tumor-sagittal-crops-512x512_weights_best.hdf5
# Epoch 10/28
# 1250/1250 [==============================] - 1340s 1s/step - loss: 0.2438 - dice_coef: 0.7562 - iou_coef: 0.6377 - val_loss: 0.3697 - val_dice_coef: 0.6298 - val_iou_coef: 0.4935
#
# Epoch 00010: val_dice_coef did not improve from 0.64899
# Epoch 11/28
# 1250/1250 [==============================] - 1363s 1s/step - loss: 0.2398 - dice_coef: 0.7602 - iou_coef: 0.6434 - val_loss: 0.3925 - val_dice_coef: 0.6065 - val_iou_coef: 0.4680
#
# Epoch 00011: val_dice_coef did not improve from 0.64899
# Epoch 12/28
# 1250/1250 [==============================] - 1358s 1s/step - loss: 0.2243 - dice_coef: 0.7757 - iou_coef: 0.6579 - val_loss: 0.3871 - val_dice_coef: 0.6121 - val_iou_coef: 0.4741
#
# Epoch 00012: val_dice_coef did not improve from 0.64899
# Epoch 13/28
# 1250/1250 [==============================] - 1377s 1s/step - loss: 0.2208 - dice_coef: 0.7792 - iou_coef: 0.6634 - val_loss: 0.3645 - val_dice_coef: 0.6358 - val_iou_coef: 0.4967
#
# Epoch 00013: val_dice_coef did not improve from 0.64899
# Epoch 14/28
# 1250/1250 [==============================] - 1384s 1s/step - loss: 0.2177 - dice_coef: 0.7823 - iou_coef: 0.6695 - val_loss: 0.3715 - val_dice_coef: 0.6288 - val_iou_coef: 0.4919
#
# Epoch 00014: val_dice_coef did not improve from 0.64899
# Epoch 15/28
# 1250/1250 [==============================] - 1361s 1s/step - loss: 0.2116 - dice_coef: 0.7884 - iou_coef: 0.6742 - val_loss: 0.3719 - val_dice_coef: 0.6276 - val_iou_coef: 0.4896
#
# Epoch 00015: val_dice_coef did not improve from 0.64899
# Epoch 16/28
# 1250/1250 [==============================] - 1387s 1s/step - loss: 0.2104 - dice_coef: 0.7896 - iou_coef: 0.6779 - val_loss: 0.3801 - val_dice_coef: 0.6202 - val_iou_coef: 0.4851
#
# Epoch 00016: val_dice_coef did not improve from 0.64899
# Epoch 17/28
# 1250/1250 [==============================] - 1384s 1s/step - loss: 0.2133 - dice_coef: 0.7867 - iou_coef: 0.6748 - val_loss: 0.3792 - val_dice_coef: 0.6213 - val_iou_coef: 0.4861
#
# Epoch 00017: val_dice_coef did not improve from 0.64899
# Epoch 18/28
# 1250/1250 [==============================] - 1368s 1s/step - loss: 0.2067 - dice_coef: 0.7933 - iou_coef: 0.6825 - val_loss: 0.3722 - val_dice_coef: 0.6283 - val_iou_coef: 0.4908
#
# Epoch 00018: val_dice_coef did not improve from 0.64899
# Epoch 19/28
# 1250/1250 [==============================] - 1336s 1s/step - loss: 0.1967 - dice_coef: 0.8033 - iou_coef: 0.6934 - val_loss: 0.3808 - val_dice_coef: 0.6196 - val_iou_coef: 0.4856
#
# Epoch 00019: val_dice_coef did not improve from 0.64899
# Epoch 20/28
# 1250/1250 [==============================] - 1335s 1s/step - loss: 0.2046 - dice_coef: 0.7954 - iou_coef: 0.6860 - val_loss: 0.3574 - val_dice_coef: 0.6416 - val_iou_coef: 0.5032
#
# Epoch 00020: val_dice_coef did not improve from 0.64899
# Epoch 21/28
# 1250/1250 [==============================] - 1378s 1s/step - loss: 0.2016 - dice_coef: 0.7984 - iou_coef: 0.6891 - val_loss: 0.3764 - val_dice_coef: 0.6237 - val_iou_coef: 0.4876
#
# Epoch 00021: val_dice_coef did not improve from 0.64899
# Epoch 22/28
# 1250/1250 [==============================] - 1373s 1s/step - loss: 0.1941 - dice_coef: 0.8059 - iou_coef: 0.6967 - val_loss: 0.3956 - val_dice_coef: 0.6037 - val_iou_coef: 0.4708
#
# Epoch 00022: val_dice_coef did not improve from 0.64899
# Epoch 23/28
# 1250/1250 [==============================] - 1357s 1s/step - loss: 0.1937 - dice_coef: 0.8063 - iou_coef: 0.6981 - val_loss: 0.3817 - val_dice_coef: 0.6185 - val_iou_coef: 0.4818
#
# Epoch 00023: val_dice_coef did not improve from 0.64899
# Epoch 24/28
# 1250/1250 [==============================] - 1357s 1s/step - loss: 0.1942 - dice_coef: 0.8058 - iou_coef: 0.6975 - val_loss: 0.3702 - val_dice_coef: 0.6288 - val_iou_coef: 0.4907
#
# Epoch 00024: val_dice_coef did not improve from 0.64899

# %%
model.save_weights("last_epoch_tumor_model.hdf5")

# %%
import pandas as pd
# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(history.history) 

# save to json:  
hist_json_file = './log/tumor_coronal_crops_history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv: 
hist_csv_file = './log/tumor_coronal_crops_history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(history.history['loss'], '-', label = 'Loss')
ax1.plot(history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(np.array(history.history['dice_coef']), '-', 
         label = 'Dice Coefficient')
ax2.plot(np.array(history.history['val_dice_coef']), '-',
         label = 'Validation Dice Coefficient')
ax2.legend()
