# %%
from utils import *

# %%
import os

data_path = "D:/Study/Thesis/LiTS/datasets"
dst_path = "D:/Study/Thesis/LiTS/datasets-png"
sub_folder = os.listdir(data_path)

# %%
for folder in sub_folder:
    file_names = os.listdir(os.path.join(data_path, folder))
    for file_name in file_names:
        file_path = os.path.join(data_path, folder, file_name)
        if 'volume' in file_name:
            ct_path = os.path.join(dst_path, sub_folder, 'ct/ct')
            nifti_to_png(nifti_path=file_path, file_name=file_name, png_path=ct_path, ct=True)
        if 'segmentation' in file_name:
            liver_path = os.path.join(dst_path, sub_folder, 'liver_seg/liver_seg')
            tumor_path = os.path.join(dst_path, sub_folder, 'tumor_seg/tumor_seg')
            nifti_to_png(nifti_path=file_path, file_name=file_name, png_path=liver_path, liver_seg=True)     
            nifti_to_png(nifti_path=file_path, file_name=file_name, png_path=tumor_path, tumor_seg=True)
# Out:
# D:/Study/Thesis/LiTS/datasets\test\volume-101.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-102.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-103.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-104.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-105.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-106.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-107.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-108.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-109.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-110.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-111.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-112.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-113.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-114.nii
# D:/Study/Thesis/LiTS/datasets\test\volume-115.nii
# D:/Study/Thesis/LiTS/datasets\train\volume-0.nii
# D:/Study/Thesis/LiTS/datasets\train\volume-1.nii
# D:/Study/Thesis/LiTS/datasets\train\volume-10.nii
# D:/Study/Thesis/LiTS/datasets\train\volume-100.nii
# ...
